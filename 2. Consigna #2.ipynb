# %% [markdown]
# # Consigna #2:

# %% [markdown]
# ## 1.- Crear una tabla en una BBDD e insertar un set de datos desde un CSV
#
#
# 1. Revise el archivo **<font color='red'>oscar.csv</font>** compartido en este deepnote para identificar el tipo de dato de cada columna, y establezca los nombres apropiados para usar en el punto siguiente (atributos de la tabla):
#
# 2. Crear una tabla en la **BBDD** **<font color='red'>netflix</font>** seleccionada en la **consigna #1**, con las siguientes características:
# <center><table>
#     <tr>
#         <th colspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Nombre de la Tabla</font></th>
#         <td colspan = "3"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">oscar</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Columna</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Tipo</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Nulo</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>CHARACTER SET</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>COLLATE</font></th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>A</font></th>
#         <td rowspan = "4"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Entero</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">No permitido</td>
#         <td rowspan = "4"; colspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>B</font></th>
#         <td rowspan = "19"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Por defecto</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>C</font></th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>D</font></th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>E</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Texto hasta 128 caracteres</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4_general_ci</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>F</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Entero</td>
#         <td colspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>G</font></th>
#         <td rowspan ="2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Texto hasta 256 caracteres</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4_general_ci</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>H</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4_general_ci</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>I</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">tinyint</td>
#         <td colspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>J</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Texto hasta 128 caracteres</td>
#         <td rowspan = "5"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4</td>
#         <td rowspan = "5"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4_general_ci</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>K</font></th>
#         <td rowspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Texto hasta 512 caracteres</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>L</font></th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>M</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Texto hasta 256 caracteres</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>N</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Texto hasta 128 caracteres</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>O</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Doble</td>
#         <td colspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>P</font></th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Texto hasta 128 caracteres</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">utf8mb4_general_ci</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Q</font></th>
#         <td rowspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Doble</td>
#         <td rowspan = "2"; colspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>R</font></th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>S</font></th>
#         <td rowspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Entero</td>
#         <td rowspan = "2"; colspan = "2"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>T</font></th>
#     </tr>
# </table></center></br>
#
# 3. Importar el archivo **<font color='red'>oscar.csv</font>** en la tabla creada en el punto 2 de la **BBDD** **<font color='red'>netflix</font>** escogida en la **consigna #1**:
#
#
# 4. Construir y completar el cuadro siguiente **para la tabla oscar luego del paso 3,** según el siguiente modelo.  Los textos en <font color='blue'>azul</font> debes sustuirlos por los textos que correspondan:
# <center>
# <table>
#     <tr>
#         <td > </td>
#         <th colspan="3", style="border: 1px solid black; padding: 0px 10px 0px 10px">Nombre de la BBDD y su tabla</th>
#         <td colspan="3", style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>netflix.oscar</font></td>
#     </tr>
#     <tr>
#         <td > </td>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='black'>No nulos</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='black'>Vacios</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='black'>Nulos</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='black'>Distintos</font></th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_oscar</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_inf</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>530</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_res</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2754</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>id_content</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>444</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2314</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>78</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>title_oscar</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>530</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>year_ceremony</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>91</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>category</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>93</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>name</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2164</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>winner</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>directed_by</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2753</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>5</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>391</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>based_on</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>1360</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>1398</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>225</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>starring</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2628</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>103</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>490</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>distributed_by</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2652</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>106</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>210</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>budget</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2497</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>261</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>246</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>budget_x_million</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2476</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>282</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>153</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>box_office</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2526</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>232</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>420</font></td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>box_office_x_million</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2519</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>239</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>401</font></td>
#     </tr>
#      <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>imbd</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2621</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>137</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>38</font></td>
#     </tr>
#      <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>metascore</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2485</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>273</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>63</font></td>
#     </tr>
#      <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>rotten_tomatoes</th>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>2758</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>0</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>63</font></td>
#     </tr>
# </table></center></br>
#
# 5. Realizar las siguientes consultas sobre el conjunto de tablas que sean necesarios. Los nombres de las columnas deben mostrarse en español:
#     <b>A.</b> Seleccionar los títulos con runtime superior a 90 y lenguaje Francés. Incluir el tipo de contenido. Ordenar los títulos de menor a mayor.
#     <b>B.</b> Seleccionar aquellos títulos que posean director y país de origen. Filtrar por aquellas que tengan un Runtime mayor a 70. Ordenar los títulos de manera ascendente.
#     <b>C.</b> Sume el Runtime de las películas que tengan como único país de origen United States, India, Japan, Spain y Mexico, discriminando y ordenando por país. Incluya la columna género.
#     <b>D.</b> Mostrar las películas clasificadas como **drama** por netflix, que hayan ganado el Oscar entre 2010 y 2020 y que estén en esta plataforma
#     <b>E.</b> Seleccionar el título y el género de las películas puntuadas por IMDB entre 7 y 9. Obtener los títulos en idioma inglés.
#     <b>F.</b> Cuente la cantidad de títulos de cada género de la tabla productions. Ordene de manera descendente por las cantidades y ascendente por el género.
#     <b>G.</b> Analizar la relación entre Budget y Box Office. Calcular el ratio Budget/Box Office para las peliculas con un puntaje IMDB entre 7 y 9, sin mostrar nulos y no repetidos.
#     <b>H.</b> Obtener las películas que ganaron el Oscar a Best Picture, ordenadas de manera descendente por año ganador.
#     <b>I.</b> Mostrar el título y el año de ceremonia de los oscar para las peliculas puntuadas por IMDB entre 7 y 9. Ordenarlos alfabéticamente por títulos y de mayor a menor por año de ceremonia.
#     <b>J.</b> Mostrar una lista de las películas originales de netflix ganadoras del oscar (si las hubiera) mostrando las columnas title, category, genre runtime, el imdb_score, la premiere y el año de la ceremonia.
#     <b>K.</b> Mostrar una lista de las nominaciones al oscar de películas originales de netflix (si las hubiera) que no fueron ganadoras del premio,mostrando las columnas título, category y año de la ceremonia.
#
# 5. Documentar todo lo anterior en DEEPNOTE:
#     * Crea el cuadro del punto 4.
#     * Pega los códigos de las queries del punto 5 y agrega una captura de pantalla de la ejecución en el Administrador de BBDD, que incluya la barra de tareas de tu sistema operativo.
#     * No olvides que debes colocar el archivo de la BBDD **netflix_mod_est** en la carpeta **mi_proyecto**.
# 6. <font color='green'>**DESAFIOS**</font>:
#     Realizar las siguientes consultas sobre el conjunto de tablas que sean necesarios. Los nombres de las columnas deben mostrarse en español:
#     <b>I.</b> Cuente los tipos de contenido de la tabla “content”. Muestre la descripción de tipos en el resultado de la consulta.
#     <b>II.</b> Seleccionar títulos con duración igual a 90 min, que provengan únicamente de United States. Mostrar listed_in. Ordenar los títulos de menor a mayor.
#     <b>III.</b> Realizar una consulta similar a la anterior, en donde el campo ‘country’ contenga a United States o a UNITED STATES y el título listado contenga a ‘Horror Movie’ O HORROR MOVIE.
#     <b>IV.</b>  Mostar la lista de películas puntuadas 85 o más por Metascore que ganaron el Oscar.

# %% [markdown]
# ### 5.

# %% [markdown]
# ### A.

# %% [markdown]
# SELECT title_production AS 'título', genre AS 'tipo_de_contenido', runtime AS 'duración'
# FROM production
# WHERE runtime>'90' AND language = 'French'
# ORDER BY runtime ASC;

# %% [markdown]
# ### B.

# %% [markdown]
# SELECT title_content AS 'título', director AS 'director', country AS 'país', runtime AS 'duración'
# FROM content
# JOIN production
# ON content.id_content = production.id_content
# WHERE director IS NOT NULL AND country IS NOT NULL AND runtime>70
# ORDER BY title_content ASC;

# %% [markdown]
# ### C.

# %% [markdown]
# SELECT country AS  'país', genre AS 'género' , SUM(runtime) AS 'suma_duración'
# FROM production
# JOIN content
# ON production.id_content = content.id_content
# WHERE country IN('United States','India','Japan','Spain','Mexico')
# GROUP BY country, genre
# ORDER BY country, genre ASC;

# %% [markdown]
# ### D.

# %% [markdown]
# SELECT DISTINCT title_oscar AS 'título_oscar', year_ceremony AS 'año_ceremonia'
# FROM oscar
# WHERE year_ceremony BETWEEN '2010' AND '2020' AND winner = 1 AND id_content IN(
# SELECT id_content
# FROM content
# WHERE listed_in
# LIKE '%Drama%');

# %% [markdown]
# ### E.

# %% [markdown]
# SELECT title_production AS 'título', genre AS 'género', language AS 'idioma'
# FROM production
# WHERE imdb_score BETWEEN 7 AND 9 AND language = 'English';

# %% [markdown]
# ### F.

# %% [markdown]
# SELECT COUNT(title_production) AS 'cantidad_titulos', genre AS 'género'
# FROM production
# GROUP BY genre
# ORDER BY COUNT(title_production) DESC, genre ASC;

# %% [markdown]
# ### G.

# %% [markdown]
# SELECT DISTINCT title_oscar AS 'título' , year_ceremony AS 'Año_ceremonia',
# IF (imdb BETWEEN 7 AND 9, ROUND (budget_x_million/box_office_x_million,2), 'No aplica') AS 'ratio presupuesto/ventas'
# FROM oscar
# WHERE IF (imdb BETWEEN 7 AND 9, ROUND (budget_x_million/box_office_x_million,2), 'No aplica') IS NOT NULL;

# %% [markdown]
# ### H.

# %% [markdown]
# SELECT year_ceremony AS 'año_ganador', title_oscar AS 'título_oscar'
# FROM oscar
# WHERE category LIKE '%best picture%' AND winner = 1
# ORDER BY year_ceremony DESC, title_oscar ASC;

# %% [markdown]
# ### I.

# %% [markdown]
# SELECT DISTINCT title_oscar AS 'título_oscar', year_ceremony AS 'año_ganador'
# FROM oscar
# WHERE imdb BETWEEN 7 AND 9
# ORDER BY title_oscar ASC, year_ceremony DESC;

# %% [markdown]
# ### J.

# %% [markdown]
# SELECT title_oscar AS 'título_oscar', category AS 'categoria', genre AS 'género', runtime AS 'tiempo_de_ejecución', imdb_score AS     'imdb_puntaje' , premiere AS 'estreno', year_ceremony AS 'año_de_ceremonia'
# FROM oscar
# JOIN production
# ON oscar.id_content = production.id_content
# WHERE winner = 1;

# %% [markdown]
# ### K.

# %% [markdown]
# SELECT title_oscar AS 'título_oscar', category AS 'categoria', year_ceremony AS 'año_de_ceremonia'
# FROM oscar
# INNER JOIN production
# ON oscar.id_content = production.id_content
# WHERE winner = 0;

# %% [markdown]
# ### 7.

# %% [markdown]
# ### I.

# %% [markdown]
# SELECT DISTINCT `type`
# FROM content;

# %% [markdown]
# ### II.

# %% [markdown]
# SELECT title_content AS 'título', listed_in AS 'listado'
# FROM content
# WHERE duration LIKE '%90%' AND country = 'united states'
# ORDER BY title_content ASC;

# %% [markdown]
# ### III.

# %% [markdown]
# SELECT title_content AS 'título', listed_in AS 'listado'
# FROM content
# WHERE country LIKE '%united states%' AND listed_in LIKE '%horror movie%'
# ORDER BY title_content ASC;

# %% [markdown]
# ### IV.

# %% [markdown]
# SELECT DISTINCT title_oscar AS 'título_oscar'
# FROM oscar
# WHERE metascore>85 AND winner = 1;

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7980bf71-2afe-4691-889b-dcc069bc831c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
